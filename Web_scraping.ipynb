# %%
# script to scrape tweets by a twitter user.
# Author - ThePythonDjango.Com
# dependencies - BeautifulSoup, requests

from bs4 import BeautifulSoup
import requests
import sys
import json


def usage():
    msg = """
    Please use the below command to use the script.
    python script_name.py twitter_username
    """
    print(msg)
    sys.exit(1)


def get_username():
    # if username is not passed
    if len(sys.argv) < 2:
        usage()
    username = sys.argv[1].strip().lower()
    if not username:
        usage()

    return username


def start(username = None):
    username = get_username()
    url = "http://www.twitter.com/" + username
    print("\n\nDownloading tweets for " + username)
    response = None
    try:
        response = requests.get(url)
    except Exception as e:
        print(repr(e))
        sys.exit(1)
    
    if response.status_code != 200:
        print("Non success status code returned "+str(response.status_code))
        sys.exit(1)

    soup = BeautifulSoup(response.text, 'lxml')

    if soup.find("div", {"class": "errorpage-topbar"}):
        print("\n\n Error: Invalid username.")
        sys.exit(1)

    tweets = get_tweets_data(username, soup)

# %%
start(username='narendramodi')
# Out:
# ...
# Non success status code returned 404
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
username = 'narendramodi'
url = "http://www.twitter.com/" + username

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" data-scribe-reduced-action-queue="true">\n  <head>\n    \n    \n    \n    \n    \n    \n    \n    <meta charset="utf-8">\n      <script  nonce="TmVWFYaujW9f3oLLCfbV+w==">\n        !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();\n      </script>\n    \n    \n  \n  <script id="bouncer_terminate_iframe" nonce="TmVWFYaujW9f3oLLCfbV+w==">\n    if (window.top != window) {\n  window.top.postMessage({\'bouncer\': true, \'event\': \'complete\'}, \'*\');\n}\n  </script>\n  <script id="swift_action_queue" nonce="TmVWFYaujW9f3oLLCfbV+w==">\n    !function(){function e(e){if(e||(e=window.event),!e)return!1;if(e.timestamp=(new Date).getTime(),!e.target&&e.srcElement&&(e.target=e.srcElement),document.documentElement.getAttribute("data-scribe-reduced-action-queue"))for(var t=e.target;t&&t!=document.body;)
# ...

# %%
response.headers
# Out:
# {'cache-control': 'no-cache, no-store, must-revalidate, pre-check=0, post-check=0', 'content-encoding': 'gzip', 'content-length': '69290', 'content-type': 'text/html;charset=utf-8', 'date': 'Sat, 23 May 2020 23:44:21 GMT', 'expires': 'Tue, 31 Mar 1981 05:00:00 GMT', 'last-modified': 'Sat, 23 May 2020 23:44:21 GMT', 'pragma': 'no-cache', 'server': 'tsa_a', 'set-cookie': 'fm=0; Max-Age=0; Expires=Sat, 23 May 2020 23:44:21 GMT; Path=/; Domain=.twitter.com; Secure; HTTPOnly, _twitter_sess=BAh7CSIKZmxhc2hJQzonQWN0aW9uQ29udHJvbGxlcjo6Rmxhc2g6OkZsYXNo%250ASGFzaHsABjoKQHVzZWR7ADoPY3JlYXRlZF9hdGwrCANX7ENyAToMY3NyZl9p%250AZCIlZTBkY2UxZjM4M2NkZGE5ODRhOWJmZjlkMDUwYjNhYWI6B2lkIiVmZjE4%250ANWY3MWE0YTViYTZkMDA3MzRmMTA1MDRiNzJmOA%253D%253D--ef6835ce754cd767a75641a5f72ef115050a06db; Path=/; Domain=.twitter.com; Secure; HTTPOnly, ct0=342fcb28ca605f577e2b1f9bc3ce5351; Max-Age=21600; Expires=Sun, 24 May 2020 05:44:21 GMT; Path=/; Domain=.twitter.com; Secure', 'status': '200 OK', 'strict-transport-securi
# ...

# %%
# soup
soup = BeautifulSoup(response.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-scribe-reduced-action-queue="true" lang="en">
# <head>
# <meta charset="utf-8"/>
# <script nonce="HGXCM9O1hvFp+EleO78ykg==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
# <script id="bouncer_terminate_iframe" nonce="HGXCM9O1hvFp+EleO78ykg==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
# <script id="swift_action_queue" nonce="HGXCM9O1hvFp+EleO78ykg==">
# ...

# %%
tag = soup.b

# %%
tag.name
# Out:
# 'b'

# %%
soup.script
# Out:
# <script nonce="HGXCM9O1hvFp+EleO78ykg==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>

# %%
soup.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <script nonce="HGXCM9O1hvFp+EleO78ykg==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
# <script id="bouncer_terminate_iframe" nonce="HGXCM9O1hvFp+EleO78ykg==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
# <script id="swift_action_queue" nonce="HGXCM9O1hvFp+EleO78ykg==">
# ...

# %%
print(soup.span)
# Out:
# <span class="NoScriptForm-logo Icon Icon--logo Icon--extraLarge"></span>

# %%
tweets = soup.find_all("li", {"data-item-type": "tweet"})
tweets
# Out:
# [<li class="js-stream-item stream-item stream-item" data-item-id="1264119180653019137" data-item-type="tweet" data-suggestion-json='{"suggestion_details":{},"tweet_ids":"1264119180653019137","scribe_component":"tweet"}' id="stream-item-tweet-1264119180653019137">
# ...

# %% [markdown]
# ## Extract tweet text

# %%
def get_this_page_tweets(soup):
    tweets_list = list()
    tweets = soup.find_all("li", {"data-item-type": "tweet"})
    for tweet in tweets:
        tweet_data = None
        try:
            tweet_data = get_tweet_text(tweet)
        except Exception as e:
            continue
            #ignore if there is any loading or tweet error

        if tweet_data:
            tweets_list.append(tweet_data)
            print(".", end="")
            sys.stdout.flush()

    return tweets_list

# %%
tweet_list = []
for tweet in tweets:
    tweet_data = None
    tweet_text_box = tweet.find("p", {"class": "TweetTextSize TweetTextSize--normal js-tweet-text tweet-text"})
    # raw tweet text
    tweet_text = tweet_text_box.text
    # discarding images
    images_in_tweet_tag = tweet_text_box.find_all("a", {"class": "twitter-timeline-link u-hidden"})
    for image_in_tweet_tag in images_in_tweet_tag:
        tweet_text = tweet_text.replace(image_in_tweet_tag.text, '') # replacing image with empty string
    print(tweet_text)
    tweet_list.append(tweet_text)
# Out:
# Our people share warm and special ties, based on shared culture and values. Indians will stand by their Mauritian brothers and sisters at this difficult time.
# Thank you, Prime Minister @PKJugnauth for our warm conversation today! Congratulations for successfully controlling COVID-19 in Mauritius.
# We agreed to accelerate Indian-assisted development projects in Sri Lanka, and also strengthen investment links.
# Had an excellent talk with President @GotabayaR.  Sri Lanka is fighting COVID-19 effectively under his leadership. India will continue to support our close maritime neighbour in dealing with the pandemic and its economic impact.
# Anguished by the demise of former MP Dr. Nepal Singh Ji. He would be remembered for his numerous community service efforts. He played a key role in strengthening the BJP in Uttar Pradesh. Condolences to his family and supporters in this sad hour. Om Shanti.
# ...

# %%
# def get_this_page_tweets(soup):
#     tweets = soup.find_all("li", {"data-item-type": "tweet"})
#     tweet_list = []
#     for tweet in tweets:
#         tweet_data = None
#         tweet_text_box = tweet.find("p", {"class": "TweetTextSize TweetTextSize--normal js-tweet-text tweet-text"})
#         # raw tweet text
#         tweet_text = tweet_text_box.text
#         # discarding images
#         images_in_tweet_tag = tweet_text_box.find_all("a", {"class": "twitter-timeline-link u-hidden"})
#         for image_in_tweet_tag in images_in_tweet_tag:
#             tweet_text = tweet_text.replace(image_in_tweet_tag.text, '') # replacing image with empty string
#         print(tweet_text)
#         tweet_list.append(tweet_text)
#     return tweet_list

# %%
tweet_list[0]
# Out:
# 'Our people share warm and special ties, based on shared culture and values. Indians will stand by their Mauritian brothers and sisters at this difficult time.'

# %% [markdown]
# ## Scrapping more tweets:

# %% [markdown]
# This is the get tweets data function. We were able to get tweets from the first page, but as we load more pages, scrolling down, we get JSON response. We need to parse JSON (JavaScript Object Notation) response, which is slightly different.

# %%
def get_tweets_data(username, soup):
    tweets_list = list()
    tweets_list.extend(get_this_page_tweets(soup))

    next_pointer = soup.find("div", {"class": "stream-container"})["data-min-position"]

    while True:
        next_url = "https://twitter.com/i/profiles/show/" + username + \
                   "/timeline/tweets?include_available_features=1&" \
                   "include_entities=1&max_position=" + next_pointer + "&reset_error_state=false"

        next_response = None
        try:
            next_response = requests.get(next_url)
        except Exception as e:
            # in case there is some issue with request. None encountered so far.
            print(e)
            return tweets_list

        tweets_data = next_response.text
        tweets_obj = json.loads(tweets_data)
        if not tweets_obj["has_more_items"] and not tweets_obj["min_position"]:
            # using two checks here bcz in one case has_more_items was false but there were more items
            print("\nNo more tweets returned")
            break
        next_pointer = tweets_obj["min_position"]
        html = tweets_obj["items_html"]
        soup = BeautifulSoup(html, 'lxml')
        tweets_list.extend(get_this_page_tweets(soup))

    return tweets_list

# %%
# tweets_list = list()
# tweets_list.extend(get_this_page_tweets(soup))

# # the location of the next pointer?
# next_pointer = soup.find("div", {"class": "stream-container"})["data-min-position"]

# while True:
#     next_url = "https://twitter.com/i/profiles/show/" + username + \
#                "/timeline/tweets?include_available_features=1&" \
#                "include_entities=1&max_position=" + next_pointer + "&reset_error_state=false"

#     next_response = None
#     next_response = requests.get(next_url) # not sure what the bottom part is for
#     try:
#         next_response = requests.get(next_url)
#     except Exception as e:
#         # in case there is some issue with request. None encountered so far.
#         print(e)
#         return tweets_list

#     tweets_data = next_response.text
#     tweets_obj = json.loads(tweets_data)
#     if not tweets_obj["has_more_items"] and not tweets_obj["min_position"]:
#         # using two checks here bcz in one case has_more_items was false but there were more items
#         print("\nNo more tweets returned")
#         break
#     next_pointer = tweets_obj["min_position"]
#     html = tweets_obj["items_html"]
#     soup = BeautifulSoup(html, 'lxml')
#     tweets_list.extend(get_this_page_tweets(soup))

# %%
tweets_data = get_tweets_data('narendramodi', soup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-d438728ae876> in <module>
# ----> 1 tweets_data = get_tweets_data('narendramodi', soup)
#
# <ipython-input-78-c6717f857555> in get_tweets_data(username, soup)
#       3     tweets_list.extend(get_this_page_tweets(soup))
#       4
# ----> 5     next_pointer = soup.find("div", {"class": "stream-container"})["data-min-position"]
#       6
#       7     while True:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Out:
# <div class="NoScriptForm-content">
# <span class="NoScriptForm-logo Icon Icon--logo Icon--extraLarge"></span>
# <p>We've detected that JavaScript is disabled in your browser. Would you like to proceed to legacy Twitter?</p>
# <p class="NoScriptForm-buttonContainer"><button class="EdgeButton EdgeButton--primary" type="submit">Yes</button></p>
# </div>

# %%
# script to scrap tweets by a twitter user.
# Author - ThePythonDjango.Com
# dependencies - BeautifulSoup, requests

from bs4 import BeautifulSoup
import requests
import sys
import json


def usage():
    msg = """
    Please use the below command to use the script.
    python script_name.py twitter_username
    """
    print(msg)
    sys.exit(1)


def get_tweet_text(tweet):
    tweet_text_box = tweet.find("p", {"class": "TweetTextSize TweetTextSize--normal js-tweet-text tweet-text"})
    images_in_tweet_tag = tweet_text_box.find_all("a", {"class": "twitter-timeline-link u-hidden"})
    tweet_text = tweet_text_box.text
    for image_in_tweet_tag in images_in_tweet_tag:
        tweet_text = tweet_text.replace(image_in_tweet_tag.text, '')

    return tweet_text

def get_this_page_tweets(soup):
    tweets_list = list()
    tweets = soup.find_all("li", {"data-item-type": "tweet"})
    for tweet in tweets:
        tweet_data = None
        try:
            tweet_data = get_tweet_text(tweet)
        except Exception as e:
            continue
            #ignore if there is any loading or tweet error

        if tweet_data:
            tweets_list.append(tweet_data)
            print(".", end="")
            sys.stdout.flush()

    return tweets_list


def get_tweets_data(username, soup):
    tweets_list = list()
    tweets_list.extend(get_this_page_tweets(soup))

    next_pointer = soup.find("div", {"class": "stream-container"})["data-min-position"]

    while True:
        next_url = "https://twitter.com/i/profiles/show/" + username + \
                   "/timeline/tweets?include_available_features=1&" \
                   "include_entities=1&max_position=" + next_pointer + "&reset_error_state=false"

        next_response = None
        try:
            next_response = requests.get(next_url)
        except Exception as e:
            # in case there is some issue with request. None encountered so far.
            print(e)
            return tweets_list

        tweets_data = next_response.text
        tweets_obj = json.loads(tweets_data)
        if not tweets_obj["has_more_items"] and not tweets_obj["min_position"]:
            # using two checks here bcz in one case has_more_items was false but there were more items
            print("\nNo more tweets returned")
            break
        next_pointer = tweets_obj["min_position"]
        html = tweets_obj["items_html"]
        soup = BeautifulSoup(html, 'lxml')
        tweets_list.extend(get_this_page_tweets(soup))

    return tweets_list


# # dump final result in a json file
# def dump_data(username, tweets):
#     filename = username+"_twitter.json"
#     print("\nDumping data in file " + filename)
#     data = dict()
#     data["tweets"] = tweets
#     with open(filename, 'w') as fh:
#         fh.write(json.dumps(data))

#     return filename

# dump data into a text


def get_username():
    # if username is not passed
    if len(sys.argv) < 2:
        usage()
    username = sys.argv[1].strip().lower()
    if not username:
        usage()

    return username


def start(username = None):
    username = get_username()
    url = "http://www.twitter.com/" + username
    print("\n\nDownloading tweets for " + username)
    response = None
    try:
        response = requests.get(url)
    except Exception as e:
        print(repr(e))
        sys.exit(1)
    
    if response.status_code != 200:
        print("Non success status code returned "+str(response.status_code))
        sys.exit(1)

    soup = BeautifulSoup(response.text, 'lxml')

    if soup.find("div", {"class": "errorpage-topbar"}):
        print("\n\n Error: Invalid username.")
        sys.exit(1)

    tweets = get_tweets_data(username, soup)
    # dump data in a text file
    dump_data(username, tweets)
    print(str(len(tweets))+" tweets dumped.")

# %%
username = 'narendramodi'
url = "http://www.twitter.com/" + username
response = requests.get(url)
# soup
soup = BeautifulSoup(response.text, 'lxml')
tweets_data = get_tweets_data(username, soup)
# dump_data(username, tweets_data)  # dumps data into a json file
# Out:
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# No more tweets returned
#
# Dumping data in file narendramodi_twitter.json
# 'narendramodi_twitter.json'

# %%
len(tweets_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-125b76a19c16> in <module>
# ----> 1 len(tweets_data)
#
# NameError: name 'tweets_data' is not defined

# %%
import pandas as pd

# %%
df = pd.DataFrame(tweets_data, columns=[username])

# %%
df.head()
# Out:
#                                         narendramodi
# 0  Our people share warm and special ties, based ...
# 1  Thank you, Prime Minister @PKJugnauth for our ...
# 2  We agreed to accelerate Indian-assisted develo...
# 3  Had an excellent talk with President @Gotabaya...
# 4  Anguished by the demise of former MP Dr. Nepal...

# %%
df.shape
# Out:
# (813, 1)
